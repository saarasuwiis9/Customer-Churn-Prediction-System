# %% [markdown]
# # Customer Churn Model Training & EDA
#
# This notebook demonstrates how the data looks and trains an initial model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset generated by train.py
try:
    df = pd.read_csv('../dataset/customer_churn_data.csv')
    print("Dataset shape:", df.shape)
    display(df.head())
except FileNotFoundError:
    print("Please run src/train.py first to generate the dataset.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       4 # Load dataset generated by train.py
#       5 try:
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
if 'df' in locals():
    sns.boxplot(x='Churn', y='tenure', data=df)
    plt.title('Tenure vs Churn')
    plt.show()
